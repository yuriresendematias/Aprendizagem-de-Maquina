# %% [markdown]
# Utilizando a base de dados archive.ics.uci.edu/ml/datasets/iris:

# %%
import pandas as pd

data = pd.read_csv("iris.csv")
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      variety
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# #### 1. (25 pontos) Assumindo que cada variável segue uma distribuição normal univariada, defina a FDP a (posteriori) de cada variável dada a clase. Utilize os parâmetros média e desvio-padrão para construir a FDP Normal.

# %%
m_corr = data.corr()
m_corr
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.109369      0.871754     0.817954
# sepal.width      -0.109369     1.000000     -0.420516    -0.356544
# petal.length      0.871754    -0.420516      1.000000     0.962757
# petal.width       0.817954    -0.356544      0.962757     1.000000

# %%
import math
import numpy as np

def fdp(x, m, corr, det, inv, p):
    return (1/(math.pow(2*math.pi, p/2) * math.pow(det, 1/2))  * math.exp(-(1/2)*(x - m).dot(inv).dot((x - m).T)))

# %%
setosa = data.loc[data['variety'] == 'Iris-setosa']
setosa['variety'].unique()
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
print("---------- SETOSA ----------")
df1  = {'X':[], 'FDP':[]}
corr = setosa.corr()                #matriz de correlação
det  = np.linalg.det(corr)          #determinante da matriz de correalação
inv  = np.linalg.inv(corr)          #inversa da matriz de correlação
p    = setosa.columns.size - 1      #numero de caracteristicas
m1   = []

for i in setosa.drop(['variety'], axis=1).columns:
    m1.append(setosa[i].mean())

m1 = np.array(m1)
for i, j in setosa.drop(['variety'], axis=1).iterrows():
    x = np.array(j.to_list())
    df1['X'].append(j.to_list())
    df1['FDP'].append(fdp(x, m1, corr, det, inv, p))

pd.DataFrame(df1)
# Out:
# ---------- SETOSA ----------
#                        X       FDP
# 0   [5.1, 3.5, 1.4, 0.2]  0.042399
# 1   [4.9, 3.0, 1.4, 0.2]  0.037294
# 2   [4.7, 3.2, 1.3, 0.2]  0.040632
# 3   [4.6, 3.1, 1.5, 0.2]  0.038979
# 4   [5.0, 3.6, 1.4, 0.2]  0.041035
# 5   [5.4, 3.9, 1.7, 0.4]  0.037675
# 6   [4.6, 3.4, 1.4, 0.3]  0.035670
# 7   [5.0, 3.4, 1.5, 0.2]  0.042732
# 8   [4.4, 2.9, 1.4, 0.2]  0.035053
# 9   [4.9, 3.1, 1.5, 0.1]  0.039688
# 10  [5.4, 3.7, 1.5, 0.2]  0.039110
# 11  [4.8, 3.4, 1.6, 0.2]  0.040144
# 12  [4.8, 3.0, 1.4, 0.1]  0.038711
# 13  [4.3, 3.0, 1.1, 0.1]  0.032295
# 14  [5.8, 4.0, 1.2, 0.2]  0.027358
# 15  [5.7, 4.4, 1.5, 0.4]  0.026078
# 16  [5.4, 3.9, 1.3, 0.4]  0.036590
# 17  [5.1, 3.5, 1.4, 0.3]  0.042398
# 18  [5.7, 3.8, 1.7, 0.3]  0.032616
# 19  [5.1, 3.8, 1.5, 0.3]  0.038177
# 20  [5.4, 3.4, 1.7, 0.2]  0.034870
# 21  [5.1, 3.7, 1.5, 0.4]  0.040334
# 22  [4.6, 3.6, 1.0, 0.2]  0.028367
# 23  [5.1, 3.3, 1.7, 0.5]  0.039064
# 24  [4.8, 3.4, 1.9, 0.2]  0.035586
# ...

# %%
versicolor = data.loc[data['variety'] == 'Iris-versicolor']
versicolor['variety'].unique()
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
print("---------- VERSICOLOR ----------")
df2    = {'X':[], 'FDP':[]}
corr_2 = versicolor.corr()                #matriz de correlação
det_2  = np.linalg.det(corr_2)          #determinante da matriz de correalação
inv_2  = np.linalg.inv(corr_2)          #inversa da matriz de correlação
p_2    = versicolor.columns.size - 1      #numero de caracteristicas
m2   = []

for i in versicolor.drop(['variety'], axis=1).columns:
    m2.append(versicolor[i].mean())

m2 = np.array(m2)
for i, j in versicolor.drop(['variety'], axis=1).iterrows():
    x = np.array(j.to_list())
    df2['X'].append(j.to_list())
    df2['FDP'].append(fdp(x, m2, corr_2, det_2, inv_2, p_2))

pd.DataFrame(df2)
# Out:
# ---------- VERSICOLOR ----------
#                        X       FDP
# 0   [7.0, 3.2, 4.7, 1.4]  0.040018
# 1   [6.4, 3.2, 4.5, 1.5]  0.074058
# 2   [6.9, 3.1, 4.9, 1.5]  0.049227
# 3   [5.5, 2.3, 4.0, 1.3]  0.067651
# 4   [6.5, 2.8, 4.6, 1.5]  0.071026
# 5   [5.7, 2.8, 4.5, 1.3]  0.062101
# 6   [6.3, 3.3, 4.7, 1.6]  0.071538
# 7   [4.9, 2.4, 3.3, 1.0]  0.040098
# 8   [6.6, 2.9, 4.6, 1.3]  0.062795
# 9   [5.2, 2.7, 3.9, 1.4]  0.056270
# 10  [5.0, 2.0, 3.5, 1.0]  0.044823
# 11  [5.9, 3.0, 4.2, 1.5]  0.080694
# 12  [6.0, 2.2, 4.0, 1.0]  0.064783
# 13  [6.1, 2.9, 4.7, 1.4]  0.068092
# 14  [5.6, 2.9, 3.6, 1.3]  0.047378
# 15  [6.7, 3.1, 4.4, 1.4]  0.052141
# 16  [5.6, 3.0, 4.5, 1.5]  0.057998
# 17  [5.8, 2.7, 4.1, 1.0]  0.080168
# 18  [6.2, 2.2, 4.5, 1.5]  0.051003
# 19  [5.6, 2.5, 3.9, 1.1]  0.080887
# 20  [5.9, 3.2, 4.8, 1.8]  0.057221
# 21  [6.1, 2.8, 4.0, 1.3]  0.068298
# 22  [6.3, 2.5, 4.9, 1.5]  0.051964
# 23  [6.1, 2.8, 4.7, 1.2]  0.055022
# 24  [6.4, 2.9, 4.3, 1.3]  0.070366
# ...

# %%
virginica = data.loc[data['variety'] == 'Iris-virginica']
virginica['variety'].unique()
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
print("---------- VIRGINICA ----------")
df3    = {'X':[], 'FDP':[]}
corr_3 = virginica.corr()                #matriz de correlação
det_3  = np.linalg.det(corr_3)           #determinante da matriz de correalação
inv_3  = np.linalg.inv(corr_3)           #inversa da matriz de correlação
p_3    = virginica.columns.size - 1      #numero de caracteristicas
m3     = []

for i in virginica.drop(['variety'], axis=1).columns:
    m3.append(virginica[i].mean())

m3 = np.array(m3)
for i, j in virginica.drop(['variety'], axis=1).iterrows():
    x = np.array(j.to_list())
    df3['X'].append(j.to_list())
    df3['FDP'].append(fdp(x, m3, corr_3, det_3, inv_3, p_3))

pd.DataFrame(df3)
# Out:
# ---------- VIRGINICA ----------
#                        X       FDP
# 0   [6.3, 3.3, 6.0, 2.5]  0.022014
# 1   [5.8, 2.7, 5.1, 1.9]  0.044971
# 2   [7.1, 3.0, 5.9, 2.1]  0.057158
# 3   [6.3, 2.9, 5.6, 1.8]  0.052271
# 4   [6.5, 3.0, 5.8, 2.2]  0.055020
# 5   [7.6, 3.0, 6.6, 2.1]  0.034094
# 6   [4.9, 2.5, 4.5, 1.7]  0.011118
# 7   [7.3, 2.9, 6.3, 1.8]  0.044009
# 8   [6.7, 2.5, 5.8, 1.8]  0.054354
# 9   [7.2, 3.6, 6.1, 2.5]  0.051976
# 10  [6.5, 3.2, 5.1, 2.0]  0.049064
# 11  [6.4, 2.7, 5.3, 1.9]  0.064536
# 12  [6.8, 3.0, 5.5, 2.1]  0.059099
# 13  [5.7, 2.5, 5.0, 2.0]  0.040763
# 14  [5.8, 2.8, 5.1, 2.4]  0.038651
# 15  [6.4, 3.2, 5.3, 2.3]  0.060428
# 16  [6.5, 3.0, 5.5, 1.8]  0.064965
# 17  [7.7, 3.8, 6.7, 2.2]  0.029416
# 18  [7.7, 2.6, 6.9, 2.3]  0.015526
# 19  [6.0, 2.2, 5.0, 1.5]  0.048500
# 20  [6.9, 3.2, 5.7, 2.3]  0.061454
# 21  [5.6, 2.8, 4.9, 2.0]  0.036859
# 22  [7.7, 2.8, 6.7, 2.0]  0.025471
# 23  [6.3, 2.7, 4.9, 1.8]  0.046949
# 24  [6.7, 3.3, 5.7, 2.1]  0.063825
# ...

# %% [markdown]
# #### 2. (25 pontos) Implemente o classicador Naive Bayes utilizando FDP Normal.

# %% [markdown]
# #### 3. (25 pontos) Utilizando sua implementação e metade dos exemplos de cada classe como conjunto de treino e o resante como conjunto de teste, avalie o classicador Naive Bayes.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data.drop(['variety'], axis=1), data['variety'], test_size=0.5)

# %% [markdown]
# #### 4. (25 pontos) Faça o mesmo da questão anterior utilizando uma implementação de biblioteca com conguração semelhente ao classicador solicitado na questão anterior.

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

nb = GaussianNB()
predict = nb.fit(x_train, y_train).predict(x_test)

metrics.accuracy_score(y_test, predict)
# Out:
# 0.9466666666666667
